# %% [markdown]
# # Bank Loan Classification

# %%
#importing necessary libraries

import pandas as pd

# %%
#reading the dataset

df=pd.read_csv("Bank_loan_data.csv")

# %%
#cheaking head data

df.head()
# Out:
#    ID  Age Gender  Experience  Income  ZIP Code  Family  CCAvg  Education  \
# 0  10   34      M           9   180.0     93023       1    8.9          3
# 1  17   38      M          14   130.0     95010       4    4.7          3
# 2  19   46      M          21   193.0     91604       2    8.1          3
# 3  30   38      M          13     NaN     94104       1    3.3          2
# 4  39   42      M          18     NaN     94114       3    5.0          3
#
#    Mortgage Home Ownership  Personal Loan  Securities Account  CD Account  \
# 0         0     Home Owner              1                   0           0
# 1       134           Rent              1                   0           0
# 2         0           Rent              1                   0           0
# 3         0           Rent              1                   0           1
# 4         0           Rent              1                   1           1
#
#    Online  CreditCard
# 0     0.0           0
# 1     0.0           0
# 2     0.0           0
# 3     1.0           1
# 4     1.0           0

# %% [markdown]
# ###  Since, many columns are missing values which results in building weak machine learning model . So, we will fill those values accroding to the condition.

# %% [markdown]
# ## Performing some EDA

# %%
#checking null values present in the data set

df.isnull()
# Out:
#         ID    Age  Gender  Experience  Income  ZIP Code  Family  CCAvg  \
# 0    False  False   False       False   False     False   False  False
# 1    False  False   False       False   False     False   False  False
# 2    False  False   False       False   False     False   False  False
# 3    False  False   False       False    True     False   False  False
# 4    False  False   False       False    True     False   False  False
# ..     ...    ...     ...         ...     ...       ...     ...    ...
# 475  False  False   False       False   False     False   False  False
# 476  False  False   False       False    True     False   False  False
# 477  False  False   False       False    True     False   False  False
# 478  False  False   False       False    True     False   False  False
# 479  False  False   False       False   False     False   False  False
#
#      Education  Mortgage  Home Ownership  Personal Loan  Securities Account  \
# 0        False     False           False          False               False
# 1        False     False           False          False               False
# 2        False     False           False          False               False
# 3        False     False           False          False               False
# 4        False     False           False          False               False
# ..         ...       ...             ...            ...                 ...
# 475      False     False           False          False               False
# 476      False     False           False          False               False
# 477      False     False           False          False               False
# 478      False     False           False          False               False
# 479      False     False           False          False               False
#
#      CD Account  Online  CreditCard
# 0         False   False       False
# 1         False   False       False
# 2         False   False       False
# 3         False   False       False
# 4         False   False       False
# ..          ...     ...         ...
# 475       False   False       False
# 476       False   False       False
# 477       False   False       False
# 478       False   False       False
# 479       False   False       False
#
# [480 rows x 16 columns]

# %% [markdown]
# True represent missing values while False represent not a missing values

# %%
#checking total null values in the dataset

df.isnull().sum()
# Out:
# ID                     0
# Age                    0
# Gender                 0
# Experience             0
# Income                67
# ZIP Code               0
# Family                 0
# CCAvg                  0
# Education              0
# Mortgage               0
# Home Ownership         0
# Personal Loan          0
# Securities Account     0
# CD Account             0
# Online                40
# CreditCard             0
# dtype: int64

# %% [markdown]
# we got 67 null values in income column and 40 null values in Online(Internet Banking)

# %% [markdown]
# ### For filling missing values , we use mean , median or mode accroding to the data present to the column.

# %%
# filling empty values in  Income column . Since Income is a numeric variable , we use mean for filling missing values.

df['Income'] = df['Income'].fillna(df['Income'].mean())

# %%
#checking newly missing values total in income column

df['Income'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Now, we got no missing values in Income Column.

# %% [markdown]
# # Performing feature engineering

# %%
#checking data type of income 

df['Income'].dtype
# Out:
# dtype('float64')

# %%
#changing data type of income 

df['Income']=df['Income'].astype('int')

# %%
df['Income'].dtypes
# Out:
# dtype('int64')

# %%
# filling empty values in Online(Internet Banking) column . 
df['Online']=df['Online'].fillna(df['Online'].mode()[0])

# %%
#checking newly missing values total in Online(Internet Banking) column

df['Online'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## changing float values into int

# %%
df['Online'].dtypes
# Out:
# dtype('float64')

# %%
df['Online']=df['Online'].astype('int')

# %%
df['Online'].dtypes
# Out:
# dtype('int64')

# %%
df['CCAvg'].dtypes
# Out:
# dtype('float64')

# %%
df['CCAvg']=df['CCAvg'].astype('int')

# %%
df['CCAvg'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# ### Now, we got no missing values in Income and Online(Internet Banking) Column and also we got income ,CCAvg and Online(Internet Banking) data type as int.

# %% [markdown]
# ## Since ,column like "ID" , "ZipCode" etc does not play important role in building ML model for loan acceptance . So, we remove this column.

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'Experience', 'Income', 'ZIP Code', 'Family',
#        'CCAvg', 'Education', 'Mortgage', 'Home Ownership', 'Personal Loan',
#        'Securities Account', 'CD Account', 'Online', 'CreditCard'],
#       dtype='object')

# %%
df=df.drop(columns={'ID','ZIP Code','Mortgage'})

# %%
# the columns are dropped 

df.columns
# Out:
# Index(['Age', 'Gender', 'Experience', 'Income', 'Family', 'CCAvg', 'Education',
#        'Home Ownership', 'Personal Loan', 'Securities Account', 'CD Account',
#        'Online', 'CreditCard'],
#       dtype='object')

# %% [markdown]
# ## performing one-hot encoding to convert string values into categorical values

# %%
gender_map = {'M': 3, 'F': 2,'O':1}
df['Gender'] = df['Gender'].map(gender_map)

# %% [markdown]
# 3 represent male , 2 represent female and 1 represent others.

# %%
home_map={'Home Owner':3,'Home Mortage':2,'Rent':1}
df['Home Ownership']=df['Home Ownership'].map(home_map)

# %% [markdown]
# 3 represent Home Owner , 2 represent Home Mortage and 1 represent Rent.

# %%
#checking if there is null values present in dataset or not

df.isnull().sum()
# Out:
# Age                   0
# Gender                0
# Experience            0
# Income                0
# Family                0
# CCAvg                 0
# Education             0
# Home Ownership        0
# Personal Loan         0
# Securities Account    0
# CD Account            0
# Online                0
# CreditCard            0
# dtype: int64

# %% [markdown]
# # Detecting outliers present in the columns and removing it

# %%
df.describe()
# Out:
#               Age      Gender  Experience      Income      Family       CCAvg  \
# count  480.000000  480.000000  480.000000  480.000000  480.000000  480.000000
# mean    52.043750    2.568750   19.843750  144.106250    2.612500    3.491667
# std     74.024316    0.619332   11.582443   30.321987    1.115393    2.121550
# min      0.000000    1.000000    0.000000    8.000000    1.000000    0.000000
# 25%     34.000000    2.000000    9.000000  124.000000    2.000000    2.000000
# 50%     45.000000    3.000000   20.000000  144.000000    3.000000    3.000000
# 75%     55.000000    3.000000   30.000000  169.250000    4.000000    5.000000
# max    978.000000    3.000000   41.000000  203.000000    4.000000   10.000000
#
#         Education  Home Ownership  Personal Loan  Securities Account  \
# count  480.000000       480.00000     480.000000          480.000000
# mean     2.233333         2.03125       0.997917            0.125000
# std      0.753373         0.73750       0.045644            0.331064
# min      1.000000         1.00000       0.000000            0.000000
# 25%      2.000000         1.00000       1.000000            0.000000
# 50%      2.000000         2.00000       1.000000            0.000000
# 75%      3.000000         3.00000       1.000000            0.000000
# max      3.000000         3.00000       1.000000            1.000000
#
#        CD Account      Online  CreditCard
# count  480.000000  480.000000  480.000000
# mean     0.291667    0.641667    0.297917
# std      0.455004    0.480011    0.457820
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000
# 50%      0.000000    1.000000    0.000000
# 75%      1.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000

# %%
# we have outliers whose age is less than 18 and more than 65 . so, we remove those outliers.

df=df[(df['Age'] >= 18) & (df['Age'] <= 65)]

# %%
# we have outliers whose experience level is less than 1 and more than 10 years . so, we remove those outliers.

df=df[(df['Experience'] >= 1) & (df['Experience'] <= 10)]

# %%
# we have outliers whose CCAvg is less than 1 and more than 8. so, we remove those outliers.

df=df[(df['CCAvg'] >= 1) & (df['CCAvg'] <= 8)]

# %%
df
# Out:
#      Age  Gender  Experience  Income  Family  CCAvg  Education  \
# 0     34       3           9     180       1      8          3
# 5     32       3           7     132       4      1          2
# 9     31       3           7     135       4      3          2
# 16    29       3           3     148       3      4          1
# 35    26       3           2      60       2      3          1
# ..   ...     ...         ...     ...     ...    ...        ...
# 468   29       2           4     184       4      2          3
# 471   35       2          10     135       3      4          2
# 472   34       2           8     144       1      7          3
# 477   28       2           4     144       2      1          2
# 479   29       2           5     135       3      5          1
#
#      Home Ownership  Personal Loan  Securities Account  CD Account  Online  \
# 0                 3              1                   0           0       0
# 5                 2              0                   0           0       1
# 9                 1              1                   0           1       1
# 16                1              1                   0           0       1
# 35                3              1                   0           0       0
# ..              ...            ...                 ...         ...     ...
# 468               3              1                   0           0       1
# 471               2              1                   0           0       1
# 472               2              1                   0           0       0
# 477               2              1                   0           0       1
# 479               2              1                   0           1       1
#
#      CreditCard
# 0             0
# 5             0
# 9             1
# 16            0
# 35            0
# ..          ...
# 468           0
# 471           0
# 472           0
# 477           0
# 479           1
#
# [111 rows x 13 columns]

# %% [markdown]
# ## Now, we got proper data to train and build machine learning model.

# %%
#exporting proper original data for building ML model.

df.to_csv('finaldata.csv',index='True')

# %%
df
# Out:
#      Age  Gender  Experience  Income  Family  CCAvg  Education  \
# 0     34       3           9     180       1      8          3
# 5     32       3           7     132       4      1          2
# 9     31       3           7     135       4      3          2
# 16    29       3           3     148       3      4          1
# 35    26       3           2      60       2      3          1
# ..   ...     ...         ...     ...     ...    ...        ...
# 468   29       2           4     184       4      2          3
# 471   35       2          10     135       3      4          2
# 472   34       2           8     144       1      7          3
# 477   28       2           4     144       2      1          2
# 479   29       2           5     135       3      5          1
#
#      Home Ownership  Personal Loan  Securities Account  CD Account  Online  \
# 0                 3              1                   0           0       0
# 5                 2              0                   0           0       1
# 9                 1              1                   0           1       1
# 16                1              1                   0           0       1
# 35                3              1                   0           0       0
# ..              ...            ...                 ...         ...     ...
# 468               3              1                   0           0       1
# 471               2              1                   0           0       1
# 472               2              1                   0           0       0
# 477               2              1                   0           0       1
# 479               2              1                   0           1       1
#
#      CreditCard
# 0             0
# 5             0
# 9             1
# 16            0
# 35            0
# ..          ...
# 468           0
# 471           0
# 472           0
# 477           0
# 479           1
#
# [111 rows x 13 columns]

# %% [markdown]
# # Implementing Machine Learning Model

# %%
#importing required libraries

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn import tree
import warnings
warnings.filterwarnings('ignore')
# %load_ext autoreload
# %autoreload 2

# %%
#reading the dataset obtained after EDA and feature engineering

df_original=pd.read_csv("finaldata.csv")

# %%
#dataframe first 10 rows

df_original.head(10)
# Out:
#    Unnamed: 0  Age  Gender  Experience  Income  Family  CCAvg  Education  \
# 0           0   34       3           9     180       1      8          3
# 1           5   32       3           7     132       4      1          2
# 2           9   31       3           7     135       4      3          2
# 3          16   29       3           3     148       3      4          1
# 4          35   26       3           2      60       2      3          1
# 5          36   28       3           4     155       4      5          2
# 6          40   36       3          10     179       3      6          1
# 7          41   28       3           3     115       4      3          2
# 8          44   29       3           4     183       3      8          3
# 9          57   33       3           8     115       4      2          2
#
#    Home Ownership  Personal Loan  Securities Account  CD Account  Online  \
# 0               3              1                   0           0       0
# 1               2              0                   0           0       1
# 2               1              1                   0           1       1
# 3               1              1                   0           0       1
# 4               3              1                   0           0       0
# 5               3              1                   0           0       1
# 6               1              1                   0           0       1
# 7               1              1                   0           0       1
# 8               2              1                   0           0       1
# 9               3              1                   0           0       1
#
#    CreditCard
# 0           0
# 1           0
# 2           1
# 3           0
# 4           0
# 5           0
# 6           0
# 7           0
# 8           0
# 9           0

# %%
#dropping unnecessary columns

df_original=df_original.drop(columns={'Unnamed: 0'})

# %%
#checking data again

df_original
# Out:
#      Age  Gender  Experience  Income  Family  CCAvg  Education  \
# 0     34       3           9     180       1      8          3
# 1     32       3           7     132       4      1          2
# 2     31       3           7     135       4      3          2
# 3     29       3           3     148       3      4          1
# 4     26       3           2      60       2      3          1
# ..   ...     ...         ...     ...     ...    ...        ...
# 106   29       2           4     184       4      2          3
# 107   35       2          10     135       3      4          2
# 108   34       2           8     144       1      7          3
# 109   28       2           4     144       2      1          2
# 110   29       2           5     135       3      5          1
#
#      Home Ownership  Personal Loan  Securities Account  CD Account  Online  \
# 0                 3              1                   0           0       0
# 1                 2              0                   0           0       1
# 2                 1              1                   0           1       1
# 3                 1              1                   0           0       1
# 4                 3              1                   0           0       0
# ..              ...            ...                 ...         ...     ...
# 106               3              1                   0           0       1
# 107               2              1                   0           0       1
# 108               2              1                   0           0       0
# 109               2              1                   0           0       1
# 110               2              1                   0           1       1
#
#      CreditCard
# 0             0
# 1             0
# 2             1
# 3             0
# 4             0
# ..          ...
# 106           0
# 107           0
# 108           0
# 109           0
# 110           1
#
# [111 rows x 13 columns]

# %% [markdown]
# ## Now,we start selecting columns to build ML model.

# %%
df_original.columns
# Out:
# Index(['Age', 'Gender', 'Experience', 'Income', 'Family', 'CCAvg', 'Education',
#        'Home Ownership', 'Personal Loan', 'Securities Account', 'CD Account',
#        'Online', 'CreditCard'],
#       dtype='object')

# %%
# selecting columns to train model

x = df_original[['Age','Gender','Experience','Income','Family','CCAvg', 'Education','Home Ownership', 'Securities Account', 'CD Account','Online', 'CreditCard']] # These are the variables which we are going to train.
y = df_original['Personal Loan'] #This is target variable which we are going to predict.

# %%
#splitting the variable into training and testing set 

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42) #we keep 20% data for test and 80% data for training the model and we keep randomness at 42.

# %% [markdown]
# # Logistic Regression

# %%
# Creating a logistic regression model
model = LogisticRegression()

# Training the model
model.fit(X_train, y_train)

# Making predictions on the test set
y_pred = model.predict(X_test)

# Calculating the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy*100)
# Out:
# Accuracy: 100.0

# %% [markdown]
# ## Here, we got accuracy 100% which shows us that our model is working fine and predicting the best possible results.

# %%
#testing model using values 
#data incluse ['Age','Gender','Experience','Income','Family','CCAvg', 'Education','Mortgage','Home Ownership', 'Securities Account', 'CD Account','Online', 'CreditCard']

y_pred=model.predict([[38,3,7,132,4,1,2,2,0,0,1,0]])
y_pred[0]
# Out:
# 1

# %% [markdown]
# ### Here, we got 1 as a result which is the 'YES' in Loan Acceptance. It means the Customer who has above input values had accept the personal loan offered in the last campaign.

# %%
# saving trained model into pickle file so that model can be easily loaded and used for prediction.

import pickle
LR_Model_pkl = open('LogisticRegression.pkl', 'wb')
pickle.dump(model, LR_Model_pkl)
LR_Model_pkl.close()

# %% [markdown]
# ## DecisionTree

# %%
from sklearn.tree import DecisionTreeClassifier

DecisionTree = DecisionTreeClassifier(criterion="entropy",random_state=2,max_depth=5)

DecisionTree.fit(X_train,y_train)
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy*100)
# Out:
# Accuracy: 100.0

# %% [markdown]
# Here also , we got accuracy as 100% which is best accuracy and shows the model is working fine.

# %%
#testing model using values 
#data incluse ['Age','Gender','Experience','Income','Family','CCAvg', 'Education','Mortgage','Home Ownership', 'Securities Account', 'CD Account','Online', 'CreditCard']

y_pred=model.predict([[47,3,21,144,4,3,3,2,0,0,0,0]])
y_pred[0]
# Out:
# 1

# %% [markdown]
#  ### Here, we got 1 as a result which is the 'YES' in Loan Acceptance. It means the Customer who had above input values had accept the personal loan offered in the last campaign.

# %%
# saving trained model into pickle file so that model can be easily loaded and used for prediction.

import pickle
LR_Model_pkl = open('DecisionTree.pkl', 'wb')
pickle.dump(DecisionTree, LR_Model_pkl)
LR_Model_pkl.close()

# %% [markdown]
# # GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB

NaiveBayes = GaussianNB()

NaiveBayes.fit(X_train,y_train)
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy*100)
# Out:
# Accuracy: 100.0

# %% [markdown]
# Here also , we got accuracy as 100% which is best accuracy and shows the model is working fine.

# %%
#testing model using values 
#data incluse ['Age','Gender','Experience','Income','Family','CCAvg', 'Education','Mortgage','Home Ownership', 'Securities Account', 'CD Account','Online', 'CreditCard']

y_pred=model.predict([[34,3,9,123,1,1,2,1,0,0,1,0]])
y_pred[0]
# Out:
# 1

# %% [markdown]
#  ## Here, we got 1 as a result which is the 'YES' in Loan Acceptance. It means the Customer who had above input values had accept the personal loan offered in the last campaign.

# %%
# saving trained model into pickle file so that model can be easily loaded and used for prediction.

import pickle
LR_Model_pkl = open('GaussianNB.pkl', 'wb')
pickle.dump(NaiveBayes, LR_Model_pkl)
LR_Model_pkl.close()

# %% [markdown]
# # With this , I have build the machine learning model to predict that the customer accept the personal loan offered in the last campaign or not. Thank You.
